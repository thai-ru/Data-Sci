# %%
def f(x):
    return 2 * x + 1
x_values = [0, 1, 2, 3]

for x in x_values:
    y = f(x)
    print(y)
# Out:
# 1
# 3
# 5
# 7

# %%
import matplotlib

# %%
from sympy import *

# %%
x = symbols('x')
f = 2 * x + 1
plot(f)

# %%
x = symbols('x')
f = 2 ** x + 1
plot(f)

# %%
from sympy import *
from sympy.plotting import plot3d
x, y = symbols('x y')
f = 2*x + 3*y

# %%
plot3d(f)
